# %%
import pandas as pd

data_xlsx = pd.read_excel('gebieden_groot.xlsx', sep='\t', index=None)

# %%
data_xlsx
# Out:
#            gb/std  oppervlakte in ha  oppervlakte in ha land  bevolking  \
# 0       A Centrum             804.35                  628.60      86422
# 1          E West            1062.99                  943.08     143842
# 2    F Nieuw-West            3801.55                 3387.35     151677
# 3          K Zuid            1727.40                 1544.97     144432
# 4          M Oost            3059.49                 1778.27     135767
# 5         N Noord            6382.88                 4176.03      94766
# 6      T Zuidoost            2211.37                 2000.56      87854
# 7  ZX99 Westpoort            2899.16                 2013.45        192
# 8   ASD Amsterdam           21949.18                16472.30     844952
#
#    bevolkingsdichtheid per km2 land  woningen  woningdichtheid per km2 land  \
# 0                             13748     54026                          8595
# 1                             15252     78465                          8320
# ...

# %%
data_xlsx.to_csv('stadsdelen.csv', sep='\t', index=None)

# %%
data = pd.read_csv('stadsdelen.csv', sep='\t', index_col=None)

# %%
data
# Out:
#            gb/std  oppervlakte in ha  oppervlakte in ha land  bevolking  \
# 0       A Centrum             804.35                  628.60      86422
# 1          E West            1062.99                  943.08     143842
# 2    F Nieuw-West            3801.55                 3387.35     151677
# 3          K Zuid            1727.40                 1544.97     144432
# 4          M Oost            3059.49                 1778.27     135767
# 5         N Noord            6382.88                 4176.03      94766
# 6      T Zuidoost            2211.37                 2000.56      87854
# 7  ZX99 Westpoort            2899.16                 2013.45        192
# 8   ASD Amsterdam           21949.18                16472.30     844952
#
#    bevolkingsdichtheid per km2 land  woningen  woningdichtheid per km2 land  \
# 0                             13748     54026                          8595
# 1                             15252     78465                          8320
# ...

# %%
#del data['oppervlakte in ha']
#del data['oppervlakte in ha land']
#del data['bevolkingsdichtheid per km2 land']
#del data['woningdichtheid per km2 land']

data
# Out:
#            gb/std  bevolking  woningen gemiddelde woningbezetting
# 0       A Centrum      86422     54026                       1,60
# 1          E West     143842     78465                       1.83
# 2    F Nieuw-West     151677     64838                       2.34
# 3          K Zuid     144432     80036                       1,80
# 4          M Oost     135767     67430                       2.01
# 5         N Noord      94766     42360                       2.24
# 6      T Zuidoost      87854     40665                       2.16
# 7  ZX99 Westpoort        192        38                       5.05
# 8   ASD Amsterdam     844952    427858                       1.97

# %%
data.to_csv('stadsdelen_schoon.csv', sep='\t', index=None)
