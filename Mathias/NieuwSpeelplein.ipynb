# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
# read data
data11 = pd.read_csv('../datasets/Liander2011BEWERKT_FILTERED.csv', sep='\t')
data12 = pd.read_csv('../datasets/Liander2012BEWERKT_FILTERED.csv', sep='\t')
data13 = pd.read_csv('../datasets/Liander2013BEWERKT_FILTERED.csv', sep='\t')
data14 = pd.read_csv('../datasets/Liander2014BEWERKT_FILTERED.csv', sep='\t')
data15 = pd.read_csv('../datasets/Liander2015BEWERKT_FILTERED.csv', sep='\t')
data16 = pd.read_csv('../datasets/Liander2016BEWERKT_FILTERED.csv', sep='\t')
data17 = pd.read_csv('../datasets/Liander2017BEWERKT_FILTERED.csv', sep='\t')

# %%
data11['jaar']='2011'
data12['jaar']='2012'
data13['jaar']='2013'
data14['jaar']='2014'
data15['jaar']='2015'
data16['jaar']='2016'
data17['jaar']='2017'

# %%
frames = [data11, data12, data13, data14, data15, data16, data17]
alles = pd.concat(frames)

# %%
alles
# Out:
#       MEETVERANTWOORDELIJKE       NETBEHEERDER              STRAATNAAM  \
# 0              Liander N.V.        GAS Liander           De Ruyterkade
# 1              Liander N.V.  Liander N.V. (NW)          Oosterdokskade
# 2              Liander N.V.        GAS Liander          Oosterdokskade
# 3              Liander N.V.  Liander N.V. (NW)       Oosterdokskade AB
# 4              Liander N.V.        GAS Liander       Prins Hendrikkade
# 5              Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 6              Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 7              Liander N.V.        GAS Liander       Prins Hendrikkade
# 8              Liander N.V.        GAS Liander       Prins Hendrikkade
# 9              Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 10             Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 11             Liander N.V.        GAS Liander       Prins Hendrikkade
# ...

# %%
alles.to_csv('../datasets/LianderTotal.csv', sep='\t', index=False)
