# %%
import pandas as pd
import numpy as np
import matplotlib
data = pd.read_csv('../datasets/sicknieuwmapje/SuperLiander.csv', sep='\t')

# %%
elk = data[data['PRODUCTSOORT'] == 'ELK']

# %%
slim_list = []
for index, row in elk.iterrows():
    aantal_aansl = row['Aantal Aansluitingen']
    stat_float = float(row['%Fysieke status'].replace(',','.'))/100
    slim_float = float(row['%Slimme Meter'].replace(',','.'))/100
    aantal_slim = aantal_aansl * stat_float * slim_float
    slim_list.append(aantal_slim)

sjv_list = list(elk['SJV'])

# %%
print(len(elk))
print(len(slim_list))
print(len(sjv_list))
# Out:
# 94261
# 94261
# 94261

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.sampledata.commits import data
from bokeh.transform import jitter
from bokeh.models import CrosshairTool
from bokeh.models import LinearAxis, Range1d

# output to static HTML file
output_file("line.html")

source = ColumnDataSource(data=dict(
    x=slim_list,
    y=sjv_list
))

p = figure(plot_width=700, plot_height=700, title=':)')

# add a circle renderer with a size, color, and alpha
p.circle('x', 'y', source=source, alpha=0.5, color='red')

p.add_tools(CrosshairTool())

p.yaxis.axis_label = "Stroomverbruik"
p.xaxis.axis_label = "Aantal slimme meters"

# show the results
show(p)

# %%
elk[elk['Aantal Aansluitingen'] > 500]
# Out:
#        POSTCODE_VAN POSTCODE_TOT PRODUCTSOORT  Aantal Aansluitingen  \
# 2878         1018AK       1018AK          ELK                   533
# 28821        1018AK       1018AK          ELK                   534
# 54885        1018AK       1018AK          ELK                   533
# 81045        1018AK       1018AK          ELK                   538
# 129274       1096DE       1096GG          ELK                   525
# 140564       1054ZX       1055AA          ELK                   669
# 155543       1096GE       1096GG          ELK                   520
# 157048       1103BD       1103BG          ELK                   520
# 168515       1054ZX       1055AA          ELK                   669
# 171803       1062AC       1062AC          ELK                   513
# 183521       1096GE       1096GG          ELK                   562
#
#        %Leveringsrichting %Fysieke status   SJV %Slimme Meter      WIJKEN  \
# 2878                99,81           95,31  3369             0     CENTRUM
# ...
