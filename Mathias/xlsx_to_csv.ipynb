# %%
import pandas as pd
import numpy as np

# %%
xlsx_data = pd.read_excel('../Liander_kleinverbruiksgegevens_01012017.xlsx', index_col=None)

# %%
xlsx_data.to_csv('Liander_kleinverbruikgegevens_01012017.csv', sep='\t', index=False)

# %%
test_data = pd.read_csv('../../../Datasets/Liander_kleinverbruiksgegevens_01012016.csv', sep='\t', encoding='cp1252')

# %%
print(test_data)
# Out:
#        MEETVERANTWOORDELIJKE       NETBEHEERDER  \
# 0               Liander N.V.  Liander N.V. (NW)
# 1               Liander N.V.  Liander N.V. (NW)
# 2               Liander N.V.        GAS Liander
# 3               Liander N.V.        GAS Liander
# 4               Liander N.V.  Liander N.V. (NW)
# 5               Liander N.V.  Liander N.V. (NW)
# 6                        NaN        GAS Liander
# 7                        NaN  Liander N.V. (NW)
# 8                        NaN  Liander N.V. (NW)
# 9               Liander N.V.        GAS Liander
# 10              Liander N.V.  Liander N.V. (NW)
# 11                       NaN  Liander N.V. (NW)
# 12              Liander N.V.  Liander N.V. (NW)
# 13              Liander N.V.        GAS Liander
# 14                       NaN  Liander N.V. (NW)
# 15              Liander N.V.  Liander N.V. (NW)
# 16                       NaN        GAS Liander
# 17              Liander N.V.  Liander N.V. (NW)
# ...
