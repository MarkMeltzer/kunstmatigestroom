# %%
import pandas as pd
import numpy as np
import matplotlib
data = pd.read_csv('../datasets/LianderTotal_NIEUW.csv', sep='\t')

# %%
data
# Out:
#        POSTCODE_VAN POSTCODE_TOT PRODUCTSOORT %Leveringsrichting   SJV  \
# 0            1011AC       1011AC          GAS                100  3849
# 1            1011AD       1011AD          ELK                100  4557
# 2            1011AD       1011AE          GAS                100  1231
# 3            1011AE       1011AE          ELK                100  3231
# 4            1011AG       1011AH          GAS                100  2075
# 5            1011AH       1011AH          ELK                100  3570
# 6            1011AJ       1011AJ          ELK                100  2562
# 7            1011AJ       1011AJ          GAS                100  1496
# 8            1011AM       1011AN          GAS                100  2004
# 9            1011AN       1011AN          ELK                100  3637
# 10           1011AP       1011AP          ELK                100  4584
# 11           1011AP       1011AP          GAS                100  2345
# ...
