# %%
import pandas as pd

# Bind iedere wijk aan postcode
# Centrum -> 1011-1018
# West -> 1050-1059
# Nieuw-West -> 1060-1069
# Zuid -> 1070-1083
# Oost -> 1086-1099
# Noord -> 1020-1039
# Zuidoost -> 1100-1108
# Westpoort -> 1040-1049

data = pd.read_csv("Liander_kleinverbruiksgegevens_01012011.csv", sep='\t', encoding='cp1252')


dictio = { '1011' : 'CENTRUM', '1012' : 'CENTRUM', '1013' : 'CENTRUM'
          , '1014' : 'CENTRUM', '1015' : 'CENTRUM', '1016' : 'CENTRUM', '1017' : 'CENTRUM'
          , '1018' : 'CENTRUM', '1019' : 'CENTRUM', '1050' : 'WEST'
          , '1051' : 'WEST', '1052' : 'WEST'
          , '1053' : 'WEST', '1054' : 'WEST', '1055' : 'WEST', '1056' : 'WEST', '1057' : 'WEST'
          , '1058' : 'WEST', '1059' : 'WEST', '1060' : 'NIEUW-WEST', '1061' : 'NIEUW-WEST', '1062' : 'NIEUW-WEST'
          , '1063' : 'NIEUW-WEST', '1064' : 'NIEUW-WEST', '1065' : 'NIEUW-WEST'
          , '1066' : 'NIEUW-WEST', '1067' : 'NIEUW-WEST', '1068' : 'NIEUW-WEST'
          , '1069' : 'NIEUW-WEST', '1070' : 'ZUID', '1071' : 'ZUID', '1072' : 'ZUID', '1073' : 'ZUID', '1074' : 'ZUID'
          , '1075' : 'ZUID', '1076' : 'ZUID', '1077' : 'ZUID', '1078' : 'ZUID', '1079' : 'ZUID', '1080' : 'ZUID', '1182' : 'ZUID'
          , '1081' : 'ZUID', '1082' : 'ZUID', '1083' : 'ZUID', '1086' : 'OOST', '1087' : 'OOST', '1088' : 'OOST'
          , '1089' : 'OOST', '1090' : 'OOST', '1091' : 'OOST', '1092' : 'OOST', '1093' : 'OOST', '1094' : 'OOST'
          , '1095' : 'OOST', '1096' : 'OOST', '1097' : 'OOST', '1098' : 'OOST'
         , '1099' : 'OOST', '1020' : 'NOORD', '1021' : 'NOORD', '1022' : 'NOORD'
          , '1023' : 'NOORD', '1024' : 'NOORD', '1025' : 'NOORD', '1026' : 'NOORD', '1027' : 'NOORD'
          , '1028' : 'NOORD', '1029' : 'NOORD', '1030' : 'NOORD', '1031' : 'NOORD', '1032' : 'NOORD', '1033' : 'NOORD'
          , '1034' : 'NOORD', '1035' : 'NOORD', '1036' : 'NOORD', '1037' : 'NOORD', '1038' : 'NOORD', '1039' : 'NOORD'
          , '1100' : 'ZUIDOOST', '1101' : 'ZUIDOOST', '1102' : 'ZUIDOOST', '1103' : 'ZUIDOOST'
          , '1104' : 'ZUIDOOST', '1105' : 'ZUIDOOST', '1106' : 'ZUIDOOST', '1107' : 'ZUIDOOST', '1108' : 'ZUIDOOST'
          , '1040' : 'WESTPOORT', '1041' : 'WESTPOORT', '1042' : 'WESTPOORT', '1043' : 'WESTPOORT'
          , '1044' : 'WESTPOORT', '1045' : 'WESTPOORT', '1046' : 'WESTPOORT', '1047' : 'WESTPOORT'
          , '1048' : 'WESTPOORT', '1049' : 'WESTPOORT'
         , '1109' : 'DRIEMOND', '1110' : 'DIEMEN', '1111' : 'DIEMEN', '1112' : 'DIEMEN', '1113' : 'DIEMEN' }

# %%
wijken = []

for row in data['POSTCODE_VAN']:
    postcode = row[:4]
    wijken.append(dictio[postcode])

# %%
data['WIJKEN'] = wijken

# %%
print(data)
# Out:
#       POSTCODE_VAN POSTCODE_TOT PRODUCTSOORT %Leveringsrichting    SJV  \
# 0           1011AB       1011AB          ELK                100  15694
# 1           1011AC       1011AC          ELK                100  11739
# 2           1011AC       1011AC          GAS                100   3849
# 3           1011AD       1011AD          ELK                100   4557
# 4           1011AD       1011AE          GAS                100   1231
# 5           1011AE       1011AE          ELK                100   3231
# 6           1011AG       1011AG          ELK                100  14012
# 7           1011AG       1011AH          GAS                100   2075
# 8           1011AH       1011AH          ELK                100   3570
# 9           1011AJ       1011AJ          ELK                100   2562
# 10          1011AJ       1011AJ          GAS                100   1496
# 11          1011AK       1011AK          ELK                100   9582
# 12          1011AL       1011AM          ELK                100   7674
# 13          1011AM       1011AN          GAS                100   2004
# 14          1011AN       1011AN          ELK                100   3637
# 15          1011AP       1011AP          ELK                100   4584
# 16          1011AP       1011AP          GAS                100   2345
# 17          1011AR       1011AR          ELK                100   6919
# 18          1011AR       1011AR          GAS                100   2785
# 19          1011AS       1011AS          ELK                100   6434
# 20          1011AS       1011AV          GAS                100   5729
# 21          1011AT       1011AT          ELK                100   8217
# 22          1011AV       1011AV          ELK                100   4565
# 23          1011AW       1011AW          ELK                100   2760
# 24          1011AW       1011AW          GAS                100   1424
# 25          1011AX       1011AX          ELK                100   3748
# 26          1011AX       1011AX          GAS                100   2432
# 27          1011AZ       1011AZ          ELK                100   3718
# 28          1011AZ       1011AZ          GAS                100   2191
# 29          1011BA       1011BA          ELK                100   2076
# ...            ...          ...          ...                ...    ...
# 29221       1098VV       1098VV          ELK                100   4800
# 29222       1098VW       1098VW          ELK                100   3690
# 29223       1098VX       1098VX          ELK                100   4438
# 29224       1098VZ       1098VZ          ELK                100   3820
# 29225       1098WB       1098WB          ELK                100   3983
# 29226       1098WC       1098WC          ELK                100   4262
# 29227       1098WD       1098WD          ELK                100   4878
# 29228       1098WE       1098WE          ELK                100   4294
# 29229       1098WG       1098WG          ELK                100   5021
# 29230       1098WG       1098XA          GAS                100   1292
# 29231       1098WH       1098WH          ELK                100   2565
# 29232       1098WJ       1098WJ          ELK                100   4198
# 29233       1098WK       1098WK          ELK                100   3405
# 29234       1098WL       1098WL          ELK                100   3886
# 29235       1098WN       1098WN          ELK                100   3315
# 29236       1098WP       1098WP          ELK                100   3495
# 29237       1098WR       1098WR          ELK                100   3427
# 29238       1098WS       1098WS          ELK                100   3609
# 29239       1098WT       1098WT          ELK                100   3888
# 29240       1098XA       1098XA          ELK                100   3022
# 29241       1098XB       1098XB          ELK                100   3785
# 29242       1098XC       1099BS          ELK                100  14416
# 29243       1098XH       1099BS          GAS                100   7982
# 29244       1099BT       1099BW          ELK                100  18718
# 29245       1099BT       1099DK          GAS                100   8599
# 29246       1099BX       1099CE          ELK                100  35372
# 29247       1099CX       1099DK          ELK                100  15956
# 29248       1099QQ       1099ZZ          ELK                100  12528
# 29249       1099ZZ       1101AG          GAS                100  11348
# 29250       1182QQ       1182QQ          ELK                100  12842
#
#         WIJKEN
# 0      CENTRUM
# 1      CENTRUM
# 2      CENTRUM
# 3      CENTRUM
# 4      CENTRUM
# 5      CENTRUM
# 6      CENTRUM
# 7      CENTRUM
# 8      CENTRUM
# 9      CENTRUM
# 10     CENTRUM
# 11     CENTRUM
# 12     CENTRUM
# 13     CENTRUM
# 14     CENTRUM
# 15     CENTRUM
# 16     CENTRUM
# 17     CENTRUM
# 18     CENTRUM
# 19     CENTRUM
# 20     CENTRUM
# 21     CENTRUM
# 22     CENTRUM
# 23     CENTRUM
# 24     CENTRUM
# 25     CENTRUM
# 26     CENTRUM
# 27     CENTRUM
# 28     CENTRUM
# 29     CENTRUM
# ...        ...
# 29221     OOST
# 29222     OOST
# 29223     OOST
# 29224     OOST
# 29225     OOST
# 29226     OOST
# 29227     OOST
# 29228     OOST
# 29229     OOST
# 29230     OOST
# 29231     OOST
# 29232     OOST
# 29233     OOST
# 29234     OOST
# 29235     OOST
# 29236     OOST
# 29237     OOST
# 29238     OOST
# 29239     OOST
# 29240     OOST
# 29241     OOST
# 29242     OOST
# 29243     OOST
# 29244     OOST
# 29245     OOST
# 29246     OOST
# 29247     OOST
# 29248     OOST
# 29249     OOST
# 29250     ZUID
#
# [29251 rows x 6 columns]

# %%
data.to_csv('LIANDERNIEUW2011.csv', encoding='utf-8', sep='\t', index=False)
