# %%
import pandas as pd
import matplotlib.pyplot as plt

# read data
data = pd.read_csv("LianderTotaal.csv", sep='\t', encoding='cp1252')

del data['MEETVERANTWOORDELIJKE']
del data['NETBEHEERDER']
del data['STRAATNAAM']
del data['VERBRUIKSSEGMENT']
del data['Aantal Aansluitingen']
del data['%Fysieke status']
del data['%Soort aansluiting']
del data['Soort aansluiting Naam']
del data['%Slimme Meter']
del data['%SJV laag tarief']
del data['Gemiddeld aantal telwielen']

print(data)
# Out:
#        POSTCODE_VAN POSTCODE_TOT PRODUCTSOORT %Leveringsrichting   SJV  jaar  \
# 0            1011AC       1011AC          GAS                100  3849  2011
# 1            1011AD       1011AD          ELK                100  4557  2011
# 2            1011AD       1011AE          GAS                100  1231  2011
# 3            1011AE       1011AE          ELK                100  3231  2011
# 4            1011AG       1011AH          GAS                100  2075  2011
# 5            1011AH       1011AH          ELK                100  3570  2011
# 6            1011AJ       1011AJ          ELK                100  2562  2011
# 7            1011AJ       1011AJ          GAS                100  1496  2011
# 8            1011AM       1011AN          GAS                100  2004  2011
# 9            1011AN       1011AN          ELK                100  3637  2011
# 10           1011AP       1011AP          ELK                100  4584  2011
# ...

# %%
data.to_csv('LianderTotalBEWERKT.csv', encoding='utf-8', sep='\t', index=False)
