# %%
import pandas as pd
import matplotlib.pyplot as plt

# read data
data = pd.read_csv("..\datasets\Liander_kleinverbruiksgegevens_01012017.csv", sep='\t', encoding='cp1252')

# %%
print(data)
# Out:
#        MEETVERANTWOORDELIJKE       NETBEHEERDER  \
# 0               Liander N.V.  Liander N.V. (NW)
# 1               Liander N.V.  Liander N.V. (NW)
# 2               Liander N.V.  Liander N.V. (NW)
# 3               Liander N.V.        GAS Liander
# 4               Liander N.V.  Liander N.V. (NW)
# 5               Liander N.V.        GAS Liander
# 6               Liander N.V.  Liander N.V. (NW)
# 7               Liander N.V.  Liander N.V. (NW)
# 8               Liander N.V.        GAS Liander
# 9               Liander N.V.  Liander N.V. (NW)
# 10              Liander N.V.  Liander N.V. (NW)
# 11              Liander N.V.        GAS Liander
# 12              Liander N.V.  Liander N.V. (NW)
# 13              Liander N.V.  Liander N.V. (NW)
# 14              Liander N.V.        GAS Liander
# 15              Liander N.V.  Liander N.V. (NW)
# 16              Liander N.V.  Liander N.V. (NW)
# 17              Liander N.V.        GAS Liander
# ...

# %%
# vergelijk max en min van defintieve aansl colum
print(data["%Defintieve aansl (NRM)"].max())
print(data["%Defintieve aansl (NRM)"].min())
# Out:
# 100
# 100

# %%
del data['%Defintieve aansl (NRM)']
del data['NETGEBIED']
del data['LANDCODE']

# %%
# print file zonder de definitieve aansl, NETGEBIED en LANDCODE colom
print(data)
# Out:
#        MEETVERANTWOORDELIJKE       NETBEHEERDER              STRAATNAAM  \
# 0               Liander N.V.  Liander N.V. (NW)            Rijksweg A44
# 1               Liander N.V.  Liander N.V. (NW)           De Ruyterkade
# 2               Liander N.V.  Liander N.V. (NW)           De Ruyterkade
# 3               Liander N.V.        GAS Liander           De Ruyterkade
# 4               Liander N.V.  Liander N.V. (NW)          Oosterdokskade
# 5               Liander N.V.        GAS Liander          Oosterdokskade
# 6               Liander N.V.  Liander N.V. (NW)       Oosterdokskade AB
# 7               Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 8               Liander N.V.        GAS Liander       Prins Hendrikkade
# 9               Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 10              Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 11              Liander N.V.        GAS Liander       Prins Hendrikkade
# ...

# %%
data = data[data.WOONPLAATS == 'AMSTERDAM']

# %%
print(data)
# Out:
#       MEETVERANTWOORDELIJKE       NETBEHEERDER                STRAATNAAM  \
# 1              Liander N.V.  Liander N.V. (NW)             De Ruyterkade
# 2              Liander N.V.  Liander N.V. (NW)             De Ruyterkade
# 3              Liander N.V.        GAS Liander             De Ruyterkade
# 4              Liander N.V.  Liander N.V. (NW)            Oosterdokskade
# 5              Liander N.V.        GAS Liander            Oosterdokskade
# 6              Liander N.V.  Liander N.V. (NW)         Oosterdokskade AB
# 7              Liander N.V.  Liander N.V. (NW)         Prins Hendrikkade
# 8              Liander N.V.        GAS Liander         Prins Hendrikkade
# 9              Liander N.V.  Liander N.V. (NW)         Prins Hendrikkade
# 10             Liander N.V.  Liander N.V. (NW)         Prins Hendrikkade
# 11             Liander N.V.        GAS Liander         Prins Hendrikkade
# 12             Liander N.V.  Liander N.V. (NW)         Prins Hendrikkade
# ...

# %%
data.to_csv('..\datasets\sicknieuwmapje\Liander2017BEWERKT.csv', encoding='utf-8', sep='\t', index=False)

# %%
newdata = pd.read_csv("..\datasets\sicknieuwmapje\Liander2017BEWERKT.csv", sep='\t')

# %%
del newdata['WOONPLAATS']
print(newdata)
# Out:
#       MEETVERANTWOORDELIJKE       NETBEHEERDER              STRAATNAAM  \
# 0              Liander N.V.  Liander N.V. (NW)  De Ruyterkade Steigers
# 1              Liander N.V.        GAS Liander           De Ruyterkade
# 2              Liander N.V.  Liander N.V. (NW)           De Ruyterkade
# 3              Liander N.V.  Liander N.V. (NW)          Oosterdokskade
# 4              Liander N.V.        GAS Liander          Oosterdokskade
# 5              Liander N.V.  Liander N.V. (NW)       Oosterdokskade AB
# 6                       NaN        GAS Liander       Prins Hendrikkade
# 7                       NaN  Liander N.V. (NW)       Prins Hendrikkade
# 8                       NaN  Liander N.V. (NW)       Prins Hendrikkade
# 9              Liander N.V.  Liander N.V. (NW)       Prins Hendrikkade
# 10             Liander N.V.        GAS Liander       Prins Hendrikkade
# 11                      NaN  Liander N.V. (NW)       Prins Hendrikkade
# ...

# %%
newdata.to_csv('..\datasets\sicknieuwmapje\Liander2017BEWERKT.csv', encoding='utf-8', sep='\t', index=False)
